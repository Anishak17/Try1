# %% [markdown]
# ## **Data Visualization on Bank Marketing Data Set**
# Welcome to the Data science Challenge, in this scenario, you will be exploring about Data Visualization.
#
# - In this task you will asked to draw few plots on the Bank Marketing data.
#
#
# - You will be specifically using seaborn package to draw the plots.
#
#
# - Your plots must match with the expected plots provided in each task.
#
#
# - Give appropriate title for plots (i.e) main title, X-axis title,y-axis title as per present in the expected plots.
#
#
# - Add extra cells for coding if necessary.
#
#
# **Note** -
#
# - Finally restart and run all the cells after the completion of the challenge.

# %%
#export PATH=$PATH:"C:\Users\1953972\AppData\Local\Programs\Git"

# %%
# wget -O try1.txt "https://raw.githubusercontent.com/Anishak17/Try1/main/try1.txt" - runs only in cmd line

# %%
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/Anishak17/Try1/main/try1.txt", "try1.txt")
# Out:
# ('try1.txt', <http.client.HTTPMessage at 0x2a6a93b1cd0>)

# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Run the below cell to import the basic neccessary packages
#
#
# **Note**-
# These are basic packages which is needed to solve this challenge,kindly include appropriate modules from the below given packages to solve this challenge based on the given scenarios.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, Image

# %% [markdown]
# ### Load the dataset
#  - Load the Bank Marketing dataset from the file **Bank_Data.csv** and save it in the variable df.

# %%
df = pd.read_csv('Bank_Data.csv')
df.head()
# Out:
#       id   age          job   marital  education default  balance housing  \
# 0  19571  54.0  blue-collar   married   tertiary      no     10.0      no
# 1   5984  48.0  blue-collar   married  secondary      no   2697.0     yes
# 2  25557  56.0      retired  divorced  secondary      no   1886.0     yes
# 3   2727  38.0  blue-collar   married  secondary      no    113.0      no
# 4   6435  39.0   technician   married  secondary      no    413.0     yes
#
#   loan   contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  cellular    7   aug     150.0         2     -1         0  failure  no
# 1  yes  cellular   26   may      79.0         5     -1         0  failure  no
# 2   no  cellular   19   nov     682.0         1     -1         0  failure  no
# 3   no  cellular   13   may      25.0        10     -1         0  failure  no
# 4   no  cellular   27   may     134.0         2     -1         0  failure  no

# %%
set(df.month)
# Out:
# {'apr', 'aug', 'dec', 'feb', 'jan', 'jul', 'jun', 'mar', 'may', 'nov', 'oct'}

# %% [markdown]
# ### Question1
#
# - From the given dataset create line plots to visualize the number of campaigns for the given months. Here perform the dot plots for the months April, May and June.
#
#
# - Set figure height as 5 inches and figure width as 15 inches.
#
#
# - Set the font size of the main title as 15.
#
#
# - Set the font size of the x-axis and y-axis label as 12.
#
#
# - Save the plot as **plot1.png** with bounding box inches as tight.
#
# **Note**-
#
# - Use seaborn for this scenario.
#
#
# ### Expected Plot
#
# <img src="/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot1.png">

# %%
help(plt.title)
# Out:
# Help on function title in module matplotlib.pyplot:
#
# title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)
#     Set a title for the Axes.
#
#     Set one of the three available Axes titles. The available titles
#     are positioned above the Axes in the center, flush with the left
#     edge, and flush with the right edge.
#
#     Parameters
#     ----------
#     label : str
#         Text to use for the title
#
#     fontdict : dict
#         A dictionary controlling the appearance of the title text,
#         the default *fontdict* is::
#
#            {'fontsize': rcParams['axes.titlesize'],
#             'fontweight': rcParams['axes.titleweight'],
#             'color': rcParams['axes.titlecolor'],
#             'verticalalignment': 'baseline',
#             'horizontalalignment': loc}
#
#     loc : {'center', 'left', 'right'}, default: :rc:`axes.titlelocation`
#         Which title to set.
#
#     y : float, default: :rc:`axes.titley`
# ...

# %%
Image('expected_plots/plot1.png')

# %%
#ax =plt.figure(figsize=(15,5))
fig1, ax1 = plt.subplots(1,1,figsize=(15,5))
sns.lineplot(df,x='campaign',y='day',hue='month', hue_order = ['may','apr','jun'],marker="o",ax=ax1)
ax1.set_title('Number of Campaigns Based on Months',{'fontsize': 15, 'fontweight': 'bold'})
ax1.set_xlabel('Campaign',fontdict={'fontsize': 12})
ax1.set_ylabel('Day',fontdict={'fontsize': 12})
ax1.grid()
fig1.savefig('plot1.png',bbox_inches='tight')

# %%
#Write your code here

# %% [markdown]
# ### Question2
#
# - From the given dataset let's visualize the correlation between each variables, so create a coorelation matrix for the columns shown in the expected plot.
#
#
# - Set figure height as 10 inches and figure width as 10 inches.
#
#
# - Set the font size of the main title as 15.
#
#
# - Save the plot as **plot2.png**with bounding box inches as tight.
#
# **Note**-
#
# - Use seaborn for this scenario.
#
#
# ### Expected Plot
#
# <img src="expected_plots/plot2.png">

# %%
help(sns.heatmap)
# Out:
# Help on function heatmap in module seaborn.matrix:
#
# heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)
#     Plot rectangular data as a color-encoded matrix.
#
#     This is an Axes-level function and will draw the heatmap into the
#     currently-active Axes if none is provided to the ``ax`` argument.  Part of
#     this Axes space will be taken and used to plot a colormap, unless ``cbar``
#     is False or a separate Axes is provided to ``cbar_ax``.
#
#     Parameters
#     ----------
#     data : rectangular dataset
#         2D dataset that can be coerced into an ndarray. If a Pandas DataFrame
#         is provided, the index/column information will be used to label the
#         columns and rows.
#     vmin, vmax : floats, optional
# ...

# %%
help(plt.Text)
# Out:
# Help on class Text in module matplotlib.text:
#
# class Text(matplotlib.artist.Artist)
#  |  Text(x=0, y=0, text='', *, color=None, verticalalignment='baseline', horizontalalignment='left', multialignment=None, fontproperties=None, rotation=None, linespacing=None, rotation_mode=None, usetex=None, wrap=False, transform_rotates_text=False, parse_math=None, **kwargs)
#  |
#  |  Handle storing and drawing of text in window or data coordinates.
#  |
#  |  Method resolution order:
#  |      Text
#  |      matplotlib.artist.Artist
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self, x=0, y=0, text='', *, color=None, verticalalignment='baseline', horizontalalignment='left', multialignment=None, fontproperties=None, rotation=None, linespacing=None, rotation_mode=None, usetex=None, wrap=False, transform_rotates_text=False, parse_math=None, **kwargs)
#  |      Create a `.Text` instance at *x*, *y* with string *text*.
#  |
# ...

# %%
cols1 = ['age','balance','day','duration','campaign','pdays','previous']
corr1 = df[cols1].corr()
corr1
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.079034 -0.016885 -0.034615  0.010858 -0.033972 -0.021071
# balance   0.079034  1.000000  0.007363  0.013508 -0.006155 -0.005523  0.000614
# day      -0.016885  0.007363  1.000000 -0.033300  0.163786 -0.068898 -0.035732
# duration -0.034615  0.013508 -0.033300  1.000000 -0.083776 -0.005543 -0.007083
# campaign  0.010858 -0.006155  0.163786 -0.083776  1.000000 -0.078826 -0.035580
# pdays    -0.033972 -0.005523 -0.068898 -0.005543 -0.078826  1.000000  0.576258
# previous -0.021071  0.000614 -0.035732 -0.007083 -0.035580  0.576258  1.000000

# %%
fig2, ax2 = plt.subplots(1,1, figsize=(10,10))
sns.heatmap(corr1,annot=True,ax=ax2)
ax2.set_title("Correlation Matrix on Bank Dataset",fontdict={'fontweight':'bold'})
fig2.savefig('plot2.png',bbox_inches='tight')

# %%
display(HTML('<embed src="https://matplotlib.org/stable/api/pyplot_summary.html" height="200" width= "1100" style="filter: grayscale(100%);">'))
# Out:
# <embed src="https://matplotlib.org/stable/api/pyplot_summary.html" height="200" width= "1100" style="filter: grayscale(100%);">

# %%
display(HTML('<embed src="https://www.google.com/webhp?igu=1" height="200" width= "1100" style="opacity: 0.3;">'))
# Out:
# <embed src="https://www.google.com/webhp?igu=1" height="200" width= "1100" style="opacity: 0.3;">

# %%
display(HTML('<embed src="https://seaborn.pydata.org/api.html" height="200" width= "1100">'))
# Out:
# <embed src="https://seaborn.pydata.org/api.html" height="200" width= "1100">

# %%
display(HTML('<embed src="https://seaborn.pydata.org/api.html" height="200" width= "1100">'))
# Out:
# <embed src="https://seaborn.pydata.org/api.html" height="200" width= "1100">

# %%
display(HTML('<iframe src="https://www.google.com/webhp?igu=1"> height="100" </iframe>'))
# Out:
# <iframe src="https://www.google.com/webhp?igu=1"> height="100" </iframe>

# %%
#Write your code here

# %%
Image('/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot3.png')

# %%
#df.groupby(['housing','loan'])['job'].value_counts().unstack(2).T.plot.bar()

# %%
df2_1=df.groupby(['job','housing'])['y'].count().unstack()
df2_1.columns = ['h_no','h_yes']
df2_2=df.groupby(['job','loan'])['y'].count().unstack()
df2_2.columns = ['l_no','l_yes']
df2 = pd.concat([df2_1,df2_2],axis=1)
df2['total'] = df2.sum(axis=1)
fig3 = df2.sort_values('total',ascending=False)[['h_yes','h_no','l_yes','l_no']].plot.bar()
plt.xlabel('Job type',fontdict={'fontsize':12})
plt.ylabel('Count',fontdict={'fontsize':12})
plt.title('Job and Loan',fontdict={'fontweight':'bold','fontsize':15})
fig3 = plt.gcf()
fig3.savefig('plot3.png',bbox_inches='tight')

# %% [markdown]
# ### Question3
#
# - From the given dataset create a bar plot to visualize the count of customers with respect to the personal and housing loan based on each job category.
#
#
# - Set figure height as 5 inches and figure width as 10 inches.
#
#
# - Set the font size of the main title as 15.
#
#
# - Set the font size of the x-axis and y-axis label as 12.
#
#
# - Save the plot as **plot3.png** with bounding box inches as tight.
#
#
# **Note**-
#
# - Here h_yes,h_no is housing yes and housing no and l_yes ,l_no is the personal loan yes and personal loan no.
#
#
# - Use Pandas Dataframe Plot for this scenario.
#
#
# ### Expected Plot
#
# <img src="expected_plots/plot3.png">

# %%
#Write your code here
Image('/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot4.png')

# %%
fig4,ax4= plt.subplots(1,1,figsize=(10,5))
sns.scatterplot(data=df, x= 'campaign',y='duration',hue='month',hue_order=['jan','feb','mar','apr','may'],ax=ax4)
ax4.set_xlabel('Campaign',fontdict={'fontsize':12})
ax4.set_ylabel('Duration (in seconds)',fontdict={'fontsize':12})
ax4.set_title('Campaign vs Duration',fontdict={'fontweight':'bold','fontsize':15})
fig4.savefig('plot4.png',bbox_inches='tight')

# %% [markdown]
# ### Question4
#
# - From the given dataset create dot plots to visualize the number of campaigns with respect to the duration for the given months. Here perform the dot plots for the months January, February, March , April and May.
#
#
# - Set figure height and figure width as 10 inches.
#
#
# - Set the font size of the main title as 15.
#
#
# - Set the font size of the x-axis and y-axis label as 12.
#
#
# - Save the plot as **plot4.png** with bounding box inches as tight.
#
#
# **Note** -
#
# - Use seaborn for this scenario.
#
#
#
# ### Expected Plot
#
# <img src="expected_plots/plot4.png">

# %%
#Write your code here

# %% [markdown]
# ### Question5
#
#
# - From the given dataset create linear model plot to visualize the linear relationship between Balance and Age of the clients with respect to the client subscription (**y**).
#
#
# - Set the font size of the main title as 15.
#
#
# - Set the font size of the x-axis and y-axis label as 12.
#
#
# - Sav the plot as **plot5.png** with bounding box inches as tight.
#
#
# **Note** -
#
# - Use seaborn for this scenario.
#
#
# ### Expected Plot
#
# <img src="expected_plots/plot5.png">

# %%
Image('/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot5.png')

# %%
sns.lmplot(data=df, x='balance',y='age',hue='y')
plt.title('Balance vs Age With Respect To Client Subscription',fontdict={'fontsize':15,'fontweight':'bold'})
plt.xlabel('Balance',fontdict={'fontsize':12})
plt.ylabel('Age',fontdict={'fontsize':12})
fig5=plt.gcf()
fig5.savefig('plot5.png',bbox_inches='tight')

# %% [markdown]
# ### Question6
#
# - From the given dataset create histogram plots to visualize the data distributions of last contact duration of the clients with respect to their job type. Here perform the histogram plots for the job categories blue-collar , retired , technician , admin and management.
#
#
# - Set figure height as 5 inches and figure width as 10 inches.
#
#
# - Set the font size of the x-axis label as 12.
#
#
# - Set the font size of the main title as 15.
#
#
# - Save the plot as **plot6.png** with bounding box inches as tight.
#
#
# **Note** -
#
# - Use seaborn for this scenario.
#
#
# ### Expected Plot
#
# <img src="expected_plots/plot6.png">

# %%
Image('/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot6.png')

# %%
fig6, ax6 = plt.subplots(1,1, figsize=(10,5))
df6 = df[df.job.isin(['blue-collar','retired','technician','admin.','management'])].groupby('job')['duration']
cols = ['blue-collar','retired','technician','admin.','management']
for var in cols:
  df6.get_group(var).hist(ax=ax6,grid=False,bins=50,alpha=0.5)
ax6.legend(cols)
ax6.set_title('Last Contact Duration - Job Wise',fontdict={'fontsize':15,'fontweight':'bold'})
ax6.set_xlabel('Duration',fontdict={'fontsize':12})
fig6.savefig('plot6.png',bbox_inches='tight')

# %%
import matplotlib
help(matplotlib.axes.Axes.plot)
# Out:
# Help on function plot in module matplotlib.axes._axes:
#
# plot(self, *args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
fig6, ax6 = plt.subplots(1,1, figsize=(10,5))
df6 = df[df.job.isin(['blue-collar','retired','technician','admin.','management'])].groupby('job')['duration']
cols = ['blue-collar','retired','technician','admin.','management']
for var in cols:
  sns.histplot(df6.get_group(var),bins=50,ax=ax6,alpha=0.5,element="step",linewidth=0)
ax6.legend(cols)
ax6.set_title('Last Contact Duration - Job Wise',fontdict={'fontsize':15,'fontweight':'bold'})
ax6.set_xlabel('Duration',fontdict={'fontsize':12})
fig6.savefig('plot6.png',bbox_inches='tight')

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Place a legend on the Axes.
#
#     Call signatures::
#
#         legend()
#         legend(handles, labels)
#         legend(handles=handles)
#         legend(labels)
#
#     The call signatures correspond to the following different ways to use
#     this method:
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line, = ax.plot([1, 2, 3])
#         line.set_label('Label via method')
#         ax.legend()
#
#     .. note::
# ...

# %%
fig6 = df[df.job.isin(['blue-collar','retired','technician','admin.','management'])].groupby('job')['duration'].hist(bins=50, alpha=0.5,legend=True,grid=False,figsize=(10,5))
# Out:
# Text(0.5, 0, 'Duration')

# %%
dir(ax6)
# Out:
# ['ArtistList',
#  '_AxesBase__clear',
#  '_PROPERTIES_EXCLUDED_FROM_SET',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autotitlepos',
#  '_axes',
#  '_axes_locator',
#  '_axis_map',
#  '_axis_names',
#  '_axisbelow',
#  '_box_aspect',
#  '_callbacks',
#  '_check_no_units',
#  '_children',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_colorbars',
#  '_convert_dx',
#  '_current_image',
#  '_default_contains',
#  '_errorevery_to_mask',
# ...

# %%
#sns.histplot(df,x='duration',hue='job',hue_order=['blue-collar','retired','technician','admin','management'],bins=50,element="step")

# %%
#Write your code here

# %% [markdown]
# ### Question7
#
#
# - From the given dataset plot the histogram to visualize the data distribution for the given numerical columns as per the expected plot.
#
#
# - Here set figure height as 15 inches and figure width as 20 inches
#
#
# - Set the font size of the main title as 20.
#
#
#
# - Save the plot as **plot7.png**  with bounding box inches as tight.
#
#
# **Note**-
# - Use matplotlib for this scenario.
#
# ### Expected Plot
#
# <img src="expected_plots/plot7.png">

# %%
import cv2 as cv
img = cv.imread('/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot7.png')
plt.imshow(img)

# %%
Image('/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot7.png')

# %%
help(df.hist)
# Out:
# Help on method hist_frame in module pandas.plotting._core:
#
# hist_frame(column: 'IndexLabel' = None, by=None, grid: 'bool' = True, xlabelsize: 'int | None' = None, xrot: 'float | None' = None, ylabelsize: 'int | None' = None, yrot: 'float | None' = None, ax=None, sharex: 'bool' = False, sharey: 'bool' = False, figsize: 'tuple[int, int] | None' = None, layout: 'tuple[int, int] | None' = None, bins: 'int | Sequence[int]' = 10, backend: 'str | None' = None, legend: 'bool' = False, **kwargs) method of pandas.core.frame.DataFrame instance
#     Make a histogram of the DataFrame's columns.
#
#     A `histogram`_ is a representation of the distribution of data.
#     This function calls :meth:`matplotlib.pyplot.hist`, on each series in
#     the DataFrame, resulting in one histogram per column.
#
#     .. _histogram: https://en.wikipedia.org/wiki/Histogram
#
#     Parameters
#     ----------
#     data : DataFrame
#         The pandas object holding the data.
# ...

# %%
fig7, ax7 = plt.subplots(2, 3, figsize=(20,15))
df7 = df[['balance','day','duration','campaign','pdays', 'previous']]
for i, var in enumerate(df7):
    df7[var].hist(ax=np.array(ax7).flatten()[i],grid=False)
    np.array(ax7).flatten()[i].set_title(var)
fig7.savefig('plot7.png',bbox_inches='tight')

# %%
#df[['balance','day','duration','campaign','pdays', 'previous']].stack().reset_index().hist(legend=False,grid=False,by='level_1',column=[0],figsize=(20,15),layout=(3,3))

# %%
#Write your code here

# %%
display(HTML('<embed src="https://matplotlib.org/" width="100%" height="300">'))
#"https://matplotlib.org/stable/api"
# Out:
# <embed src="https://matplotlib.org/" width="100%" height="300">

# %%
display(HTML('<embed src="https://seaborn.pydata.org" width="1000" height="300">'))
# Out:
# <embed src="https://seaborn.pydata.org" width="1000" height="300">

# %%
# %%HTML
# <embed src="https://www.google.com/webhp?igu=1" width="100%" height="300">
# Out:
# <embed src="https://www.google.com/webhp?igu=1" width="100%" height="300">

# %%
help(df.select_dtypes)
# Out:
# Help on method select_dtypes in module pandas.core.frame:
#
# select_dtypes(include=None, exclude=None) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Return a subset of the DataFrame's columns based on the column dtypes.
#
#     Parameters
#     ----------
#     include, exclude : scalar or list-like
#         A selection of dtypes or strings to be included/excluded. At least
#         one of these parameters must be supplied.
#
#     Returns
#     -------
#     DataFrame
#         The subset of the frame including the dtypes in ``include`` and
#         excluding the dtypes in ``exclude``.
#
#     Raises
#     ------
#     ValueError
#         * If both of ``include`` and ``exclude`` are empty
#         * If ``include`` and ``exclude`` have overlapping elements
#         * If any kind of string dtype is passed in.
#
#     See Also
#     --------
#     DataFrame.dtypes: Return Series with the data type of each column.
#
#     Notes
#     -----
# ...

# %% [markdown]
# ### Question8
#
# - From the given dataset visualize the normalized relative frequency of the target class (**y**) per each category of each categorical column.
#
#
# - Here, the difference of positive counts of each category on each column divided by total positive counts and negative counts of each category on each column divided by total negative counts will be the normalized relative frequency.
#
#
# - Here set figure height as 15 inches and figure width as 20 inches.
#
#
# - Set the font size of the main title as 20.
#
#
# - Save the plot as **plot8.png**  with bounding box inches as tight.
#
#
# **Note**-
#
# - Here exclude category **other** from column **poutcome** and category **dec** from column **month**
#
#
# - Use seaborn for this scenario.
#
# ### Expected Plot
#
# <img src="expected_plots/plot8.png">

# %%
Image('/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot8.png')

# %%
df8 = df.groupby(['job','y']).apply(len).unstack()
# Out:
# y                no  yes
# job
# admin.         1755  119
# blue-collar    6500  431
# entrepreneur    574   25
# housemaid       469   22
# management     3239  277
# retired         588   75
# self-employed   568   53
# services       1499   85
# student         171   26
# technician     2824  210
# unemployed      453   37

# %%
cols8 = df.select_dtypes(exclude="number")
#df.select_dtypes(exclude=["number"]).columns
#df.dtypes[df.dtypes.isin(['object','category'])].index

# %%
fig8,ax8 = plt.subplots(3,3,figsize=(20,15))
for i, col in enumerate(df.select_dtypes(exclude="number")):
  print(df[col].value_counts())
# Out:
# blue-collar      6931
# management       3516
# technician       3034
# admin.           1874
# services         1584
# retired           663
# self-employed     621
# entrepreneur      599
# housemaid         491
# unemployed        490
# student           197
# Name: job, dtype: int64
# married     12421
# single       5238
# divorced     2341
# Name: marital, dtype: int64
# secondary    11897
# tertiary      5282
# primary       2821
# Name: education, dtype: int64
# no     19571
# yes      429
# Name: default, dtype: int64
# yes    11332
# no      8668
# Name: housing, dtype: int64
# no     16435
# yes     3565
# Name: loan, dtype: int64
# cellular     18902
# telephone     1098
# Name: contact, dtype: int64
# may    5089
# jul    3638
# aug    2978
# jun    2533
# nov    2013
# apr    1537
# feb    1331
# jan     673
# mar     153
# oct      46
# dec       9
# Name: month, dtype: int64
# failure    19436
# other        451
# success      113
# Name: poutcome, dtype: int64
# ...

# %% [markdown]
# ## All The Very Best !!!

# %%
import pip
import sys
import subprocess
def install(package):
    if hasattr(pip, 'main'):
        pip.main(['install', package])
    else:
        pip._internal.main(['install', package])

install('wget')
install('opencv-python==4.4.0.42')
import wget
url = "https://hrcdn.net/s3_pub/istreet-assets/wee8g1Bj5hd_Iw548A2uyQ/Data_Visual-1.0-py2.py3-none-any.whl"
wget.download(url)
def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])
install('Data_Visual-1.0-py2.py3-none-any.whl')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=722f6640b5edbdf64abf4b08a435ddfba0dbe964e372e9b5fae55c587ab392f3
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
! pip install https://hrcdn.net/s3_pub/istreet-assets/wee8g1Bj5hd_Iw548A2uyQ/Data_Visual-1.0-py2.py3-none-any.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from Data_Visual import evaluate
evaluate.evaluation()
# Out:
# Plot1 matches the expected plot
# Kindly try checking Plot2 again
# Plot3 matches the expected plot
# Kindly try checking Plot4 again
# Kindly try checking Plot5 again
# Kindly try checking Plot6 again
# Kindly try checking Plot7 again
# Kindly try checking Plot8 again

# %%
import cv2
def mse(imageA, imageB):
  err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
  err/=float(imageA.shape[0] * imageA.shape[1])
  return err

# %%
import shutil, os

# %%
shutil.copy("/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot1.png",'/content/')
shutil.copy("/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot3.png",'/content/')
# Out:
# '/content/plot3.png'

# %%
original_scatter=cv2.imread("/content/drive/MyDrive/wingst3-nov21n1-datavisualization/expected_plots/plot1.png")
expected_scatter=cv2.imread("plot1.png")

# %%
fig_orig1 = plt.imshow(original_scatter[:,:,::-1])

# %%
fig_exp1 = plt.imshow(expected_scatter)

# %%
original_scatter.shape
# Out:
# (473, 1230, 3)

# %%
if(mse(original_scatter, expected_scatter) <=1500.0):
  print("Plot1 matches the expected plot")
# Out:
# Plot1 matches the expected plot

# %%
import inspect

# %%
inspect.getfullargspec(sns.histplot)
# Out:
# FullArgSpec(args=['data'], varargs=None, varkw='kwargs', defaults=(None,), kwonlyargs=['x', 'y', 'hue', 'weights', 'stat', 'bins', 'binwidth', 'binrange', 'discrete', 'cumulative', 'common_bins', 'common_norm', 'multiple', 'element', 'fill', 'shrink', 'kde', 'kde_kws', 'line_kws', 'thresh', 'pthresh', 'pmax', 'cbar', 'cbar_ax', 'cbar_kws', 'palette', 'hue_order', 'hue_norm', 'color', 'log_scale', 'legend', 'ax'], kwonlydefaults={'x': None, 'y': None, 'hue': None, 'weights': None, 'stat': 'count', 'bins': 'auto', 'binwidth': None, 'binrange': None, 'discrete': None, 'cumulative': False, 'common_bins': True, 'common_norm': True, 'multiple': 'layer', 'element': 'bars', 'fill': True, 'shrink': 1, 'kde': False, 'kde_kws': None, 'line_kws': None, 'thresh': 0, 'pthresh': None, 'pmax': None, 'cbar': False, 'cbar_ax': None, 'cbar_kws': None, 'palette': None, 'hue_order': None, 'hue_norm': None, 'color': None, 'log_scale': None, 'legend': True, 'ax': None}, annotations={})

# %%
inspect.getsourcelines(evaluate)
# Out:
# (['import pip\n',
#   'import cv2\n',
#   'import numpy as np\n',
#   '\n',
#   'def install(package):\n',
#   "    if hasattr(pip, 'main'):\n",
#   "        pip.main(['install', package])\n",
#   '    else:\n',
#   "        pip._internal.main(['install', package])\n",
#   '\n',
#   "install('opencv-python==4.4.0.42')\n",
#   'score = 0\n',
#   'def mse(imageA, imageB):\n',
#   '    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)\n',
#   '    err/=float(imageA.shape[0] * imageA.shape[1])\n',
#   '\n',
#   '    return err\n',
#   'def evaluation():\n',
#   '    #Plot1\n',
#   '    try:\n',
#   '        original_scatter=cv2.imread("expected_plots/plot1.png")\n',
#   '        expected_scatter=cv2.imread("plot1.png")\n',
#   '        if(mse(original_scatter, expected_scatter) <=1500.0):\n',
#   '            print("Plot1 matches the expected plot") \n',
#   '        else:\n',
# ...

# %%
inspect.getsourcelines(evaluate.evaluation)
# Out:
# (['def evaluation():\n',
#   '    #Plot1\n',
#   '    try:\n',
#   '        original_scatter=cv2.imread("expected_plots/plot1.png")\n',
#   '        expected_scatter=cv2.imread("plot1.png")\n',
#   '        if(mse(original_scatter, expected_scatter) <=1500.0):\n',
#   '            print("Plot1 matches the expected plot") \n',
#   '        else:\n',
#   '            print("Kindly try matching Plot1 with expected plot as much as possible")\n',
#   '\n',
#   '    except:\n',
#   '        print("Kindly try checking Plot1 again")\n',
#   '\n',
#   '    #Plot2\n',
#   '    try:\n',
#   '        original_scatter=cv2.imread("expected_plots/plot2.png")\n',
#   '        expected_scatter=cv2.imread("plot2.png")\n',
#   '        if(mse(original_scatter, expected_scatter) <=1500.0):\n',
#   '            print("Plot2 matches the expected plot")\n',
#   '        else:\n',
#   '            print("Kindly try matching Plot2 with expected plot as much as possible")\n',
#   '    except:\n',
# ...

# %%
help(inspect)
# Out:
# Help on module inspect:
#
# NAME
#     inspect - Get useful information from live Python objects.
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/inspect.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module encapsulates the interface provided by the internal special
#     attributes (co_*, im_*, tb_*, etc.) in a friendlier fashion.
#     It also provides some help for examining source code and class layout.
#
#     Here are some of the useful functions provided by this module:
#
#         ismodule(), isclass(), ismethod(), isfunction(), isgeneratorfunction(),
#             isgenerator(), istraceback(), isframe(), iscode(), isbuiltin(),
# ...
